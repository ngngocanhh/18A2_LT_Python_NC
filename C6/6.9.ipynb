# %%
import threading
import time

def website(name, delay):
    print(f"Starting {name}")
    for _ in range(3):
        time.sleep(delay)
        print(f"{name}: Web {time.ctime()}")
    print(f"Exiting {name}")

print("Starting Main Thread")

threads = [
    threading.Thread(target=website, args=("Google", 1)),
    threading.Thread(target=website, args=("Yahoo", 2)),
    threading.Thread(target=website, args=("Facebook", 3))
]

for t in threads:
    t.start()

for t in threads:
    t.join()

print("Exiting Main Thread")
# Out:
# Starting Main Thread
# Starting Google
# Starting Yahoo
# Starting Facebook
# Google: Web Wed Dec 31 20:33:38 2025
# Yahoo: Web Wed Dec 31 20:33:39 2025
# Google: Web Wed Dec 31 20:33:39 2025
# Facebook: Web Wed Dec 31 20:33:40 2025
# Google: Web Wed Dec 31 20:33:40 2025
# Exiting Google
# Yahoo: Web Wed Dec 31 20:33:41 2025
# Facebook: Web Wed Dec 31 20:33:43 2025Yahoo: Web Wed Dec 31 20:33:43 2025
# Exiting Yahoo
#
# Facebook: Web Wed Dec 31 20:33:46 2025
# Exiting Facebook
# Exiting Main Thread
