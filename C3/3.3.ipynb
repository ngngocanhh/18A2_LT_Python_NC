# %%
import numpy as np

arr_a = np.array([1,2,3,2,3,4,3,4,5,6])
arr_b = np.array([7,2,10,2,7,4,9,4,9,8])

# %%
#1
arr_c = np.intersect1d(arr_a, arr_b)
print("arr_c:", arr_c)
# Out:
# arr_c: [2 4]

# %%
#2
arr_d = np.setdiff1d(arr_a, arr_b)
print("arr_d:", arr_d)
# Out:
# arr_d: [1 3 5 6]

# %%
#3
arr_e = np.array([12,6,1,9,10,3,27,8,6,25,16])
arr_f = arr_e[(arr_e >= 5) & (arr_e <= 10)]

print("arr_f:", arr_f)
# Out:
# arr_f: [ 6  9 10  8  6]
